# %% [markdown]
# <a href="https://colab.research.google.com/github/DeboraMoraes/DataScienceAluraCourse/blob/main/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafio 01: Investigar porque a classe tratamento e tao desbalanceada
# porque se trata de pesquisas em celulas, algumas pesquisas se usam drogas e outras tratamentos para a solucao de um problema
# ### Desafio 02: Plotar as 5 ultimas linhas da tabela
# data.tail()
#
# ### Desafio 03: Proporcao da classe tratamento
# dados['tratamento'].value_counts(normalize = True)
#
# ### Desafio 04: Quantos tipos de drogas foram usados
# dados['droga'].nunique()
#
# ### Desafio 05: Procurar na documentacao o metodo query
# pandas.DataFrame.query
#
# ### Desafio 06: Colocar titulo e label nos graficos (MatPlotLib.pyplot)
# dados['tempo'].value_counts().plot.bar()
# plt.title('SEU TÍTULO LINDO')
# plt.xlabel('NOME DO EIXO X')
# plt.ylabel('NOME DO EIXO Y')
# plt.show()
#
# ### Desafio 07: Renomear as colunas tirando o hifen
# dados.rename(columns={'g-0': 'g.0'})
#
# ### Desafio 08: Resumo do que voce aprendeu com os dados
# os dados sao sobre testes, existem dois tipos de testes, um serio o com a droga e o outro com controle, que seria sem droga, existem diversos tipos de drogas, cada tratamento tem o seu tempo e quantidade de doses
#
#
# ###Aula 2
#
# ### Desafio 1: Ordenar o grafico countplot
#
# ### Desafio 2: Melhorar parte estetica do grafico alterando tamanho da fonte
#
# ### Desafio 3: Plotar os histogramas com o seaborn
#
# ### Desafio 4: estudar sobre as estatisticas retornadas no .describe()
#
# ### Desafio 5: refletir sobre o tamanho das manipulacoes
#
# ### Desafio 6: fazer outras analises com o boxplot e ate com o histograma
#
# ### Desafio 7: criar resumo do que aprendi sobre os dados hoje
#
# ### Aula 3
#
# ### Desafio 1: criar tabelas de frequencia com o pandas.groupby()
#
# ### Desafio 2: normalizar o crosstab pela coluna
#
# ### Desafio 3: explorar outros agregadores
#
# ### Desafio 4: explorar o melt
#
# ### Desafio 5: calcular e analizar a correlacao entre os g's e c's. Refletir sobre os efeitos biologicos
#
# ### Desafio 6: explorar o codigo que plota a matrix de correlacao (hitmap)
#
# ### Desafio 7: resumir a aula do dia
#
# ### AUla 4
#
# ### Desafio 1: Encontrar o top 10, das acoes do MOA (inhibidor, agonista...)
#
# ### Desafio 2: Criar a coluna eh_controle para quando na linha tratamento == com_controle
#
# ### Desafio 3: Criar tres colunas binarias para indicar tempo 24, 48, 72
#
# ### Desafio 4: Explorar mais sobre merge do pandas, combinacoes de DF
#
# ### Desafio 5: Fazer analise mais detalhada considerando tempo e analise, para comparar distribuicoes (excolher uma droga e comparar como controle)
#
# ### Desafio 6: Descobrir se temos algum composto que dependem de alguma configuracao do experimento, ativa ou nao ativa nenhum MOA
#
# ### Desafio 7: Descobrir se temos algum composto que dependem de alguma configuracao do experimento, ativa MOAs diferentes
#
# ### Desafio 8: Resumo do dia
#
#
# ### Aula 5
#
# ### Desafio 1: Tentar outros modelos ou mude os parametros dos modelos testados em aula
#
# ### Desafio 2: estudar documentacao do sklearn
#
# ### Desafio 3: pesquisar o fluxograma choosing the right estimator
#
# ### Desafio 4: Teste outras problemas (perguntas) 0, 1 ou +
#
# ### Desafio 5: Escolha a droga mais utilizada e tente criar um modelo para prever esta label
#
# ### Desafio 6: Resumo do dia

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados[dados['g-0'] > 0]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
dados['droga'].nunique()
# Out:
# 3289

# %%
dados['tempo'].value_counts().plot.pie()
plt.title('SEU TÍTULO LINDO')
plt.show()

# %%
dados['tempo'].value_counts().plot.bar()
plt.title('SEU TÍTULO LINDO')
plt.xlabel('NOME DO EIXO X')
plt.ylabel('NOME DO EIXO Y')
plt.show()

# %%
dados.rename(columns={'g-0': 'g.0'})
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
mapa = {'droga': 'small_molecule'}
dados.rename(columns=mapa)
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
mapa = {'droga': 'small_molecule'}
dados.rename(columns=mapa, inplace = True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
small_molecules = dados['small_molecule'].value_counts().index[0:5]

# %%
small_molecules
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('small_molecule in @small_molecules')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10,8))
ax=sns.countplot(x= 'small_molecule', data=dados.query('small_molecule in @small_molecules'))
ax.set_title('top 5 small_molecules')
plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist(bins = 50)

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[{'g-0', 'g-1'}]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[0, 'g-0']
# Out:
# 1.062

# %%
dados.loc[:, 'g-0']
# Out:
# 0        1.0620
# 1        0.0743
# 2        0.6280
# 3       -0.5138
# 4       -0.3254
#           ...
# 23809    0.1394
# 23810   -1.3260
# 23811    0.3942
# 23812    0.6660
# 23813   -0.8598
# Name: g-0, Length: 23814, dtype: float64

# %%
dados.loc[:, 'g-0': 'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:, 'g-0': 'g-771'].describe().T
# Out:
#          count      mean       std     min       25%      50%       75%     max
# g-0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g-1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g-2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g-3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g-4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...        ...       ...       ...     ...       ...      ...       ...     ...
# g-767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g-768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g-769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g-770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g-771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# ...

# %%
dados.loc[:, 'g-0': 'g-771'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:, 'g-0': 'g-771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[:, 'c-0': 'c-99'].describe().T['max'].hist(bins=50)

# %%
dados.loc[:, 'c-0': 'c-99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x= 'g-0', data=dados)

# %%
sns.boxplot(x= 'g-0', y= 'tratamento', data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x= 'g-0', y= 'tratamento', data=dados)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
sns.scatterplot(x='g-0', y='g-3', data=dados)

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
dados[['g-0', 'g-1']]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g-0', y='g-8', data=dados)

# %%
sns.lmplot(x='g-0', y='g-8', data=dados, line_kws={'color': 'red'})

# %%
sns.lmplot(x='g-0', y='g-8', data=dados, line_kws={'color': 'red'}, col='tratamento')

# %%
sns.lmplot(x='g-0', y='g-8', data=dados, line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np
corr = dados.loc[:, 'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Aula 4

# %%
dados_resultado = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultado.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultado['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultado['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultado.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa = dados_resultado.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultado.sum()
# Out:
# id                                       id_000644bb2id_000779bfcid_000a6266aid_0015fd3...
# 5-alpha_reductase_inhibitor                                                             17
# 11-beta-hsd1_inhibitor                                                                  18
# acat_inhibitor                                                                          24
# acetylcholine_receptor_agonist                                                         190
#                                                                ...
# ubiquitin_specific_protease_inhibitor                                                    6
# vegfr_inhibitor                                                                        170
# vitamin_b                                                                               26
# vitamin_d_receptor_agonist                                                              39
# wnt_inhibitor                                                                           30
# ...

# %%
dados_resultado.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultado.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultado['n_moa'] = dados_resultado.drop('id', axis=1).sum(axis=1)
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  wnt_inhibitor  n_moa
# 0  id_000644bb2                            0  ...              0      1
# 1  id_000779bfc                            0  ...              0      0
# 2  id_000a6266a                            0  ...              0      3
# 3  id_0015fd391                            0  ...              0      0
# 4  id_001626bd3                            0  ...              0      1
#
# [5 rows x 208 columns]

# %%
dados_resultado['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
dados_resultado['n_moa'] = dados_resultado.drop('id', axis=1).sum(axis=1)

# %%
dados_resultado['ativo_moa'] = dados_resultado['n_moa'] != 0
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      2       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      6       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      2       True
#
# [5 rows x 209 columns]

# %%
pd.merge(dados, dados_resultado[['id', 'n_moa', 'ativo_moa']], on='id')
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0      id_000644bb2     com_droga     24   D1  ...  0.3801  0.4176      2       True
# 1      id_000779bfc     com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2      id_000a6266a     com_droga     48   D1  ... -1.4080  0.6931      6       True
# 3      id_0015fd391     com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4      id_001626bd3     com_droga     72   D2  ... -0.3786  0.7125      2       True
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.5258  0.4680      2       True
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2715  0.3689      2       True
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.6656  0.3808      0      False
# 23812  id_fffcb9e7c     com_droga     24   D1  ... -0.6290  0.0740      2       True
# ...

# %%
dados_combinados = pd.merge(dados, dados_resultado[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      2       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      6       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      2       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 25     id_0054388ec  com_controle     48   D1  ...  0.8976  1.0050      0      False
# 38     id_0079af0fb  com_controle     24   D1  ...  0.6498 -1.4820      0      False
# 40     id_007bfbb91  com_controle     24   D2  ...  0.8543  0.9180      0      False
# 47     id_008a986b7  com_controle     48   D2  ... -0.9245 -0.9367      0      False
# 63     id_009d8340f  com_controle     24   D2  ... -0.4326  0.9364      0      False
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ... -0.2422  0.0457      0      False
# 23747  id_ff469c482  com_controle     72   D1  ... -0.0742 -0.6777      0      False
# 23768  id_ff89331ca  com_controle     72   D2  ... -0.1748 -0.3626      0      False
# 23793  id_ffd26f361  com_controle     48   D2  ... -0.5272  0.7082      0      False
# ...

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['small_molecule'].value_counts().index[:11]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('small_molecule in @composto_principal'), y='g-0', x='small_molecule')

# %%
composto_principal = dados_combinados['small_molecule'].value_counts().index[:11]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('small_molecule in @composto_principal'), y='g-0', x='small_molecule', hue='ativo_moa')

# %%
composto_principal = dados_combinados['small_molecule'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('small_molecule in @composto_principal'), y='g-0', x='small_molecule', hue='ativo_moa')

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      2       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      6       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      2       True
#
# [5 rows x 879 columns]

# %%
dados_resultado.head(
)
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      2       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      6       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      2       True
#
# [5 rows x 209 columns]

# %%
from sklearn.model_selection import train_test_split

x_test, x_treino, y_test, y_treino = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_test, x_treino, y_test, y_treino = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_test, y_test)
# Out:
# 0.5924623379350166

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_test)
accuracy_score(y_test, previsao_dummy)
# Out:
# 0.6066348223190384

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_test, x_treino, y_test, y_treino = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_test, y_test)
# Out:
# 0.6146134061204136

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Nao Ativo', 'Ativo'])

plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_test, x_treino, y_test, y_treino = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

teste=[]
treino=[]
for i in range(1,15):
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino, y_treino)
  modelo_arvore.score(x_test, y_test)
  teste.append(modelo_arvore.score(x_test, y_test))
  treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6066348223190384,
#  0.6136685738281455,
#  0.6146134061204136,
#  0.6136160831452417,
#  0.6136685738281455,
#  0.6161881266075272,
#  0.6128812135845887,
#  0.5990761639808934,
#  0.5927772820324393,
#  0.5982363130544328,
#  0.5923048658863052,
#  0.5915699963256522,
#  0.5832764684268542,
#  0.5841688100362186]

# %%
treino
# Out:
# [0.6067604450976275,
#  0.6229267268528238,
#  0.6290153264749108,
#  0.6460214150745328,
#  0.6584085660298131,
#  0.6726852823850514,
#  0.6836027713625866,
#  0.7037581356288054,
#  0.7239134998950242,
#  0.739869829939114,
#  0.7619147596052908,
#  0.7826999790048289,
#  0.8078941843376024,
#  0.8328784379592694]

# %%
sns.lineplot(x=range(1,15), y=teste, label='teste')
sns.lineplot(x=range(1,15), y=treino, label='treino')

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['dose', 'tratamento', 'tempo'])
# Out:
#                  id small_molecule     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2      b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc      df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a      18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391      8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3      7cbed3131 -0.3254  ...         0         0         1
# ...             ...            ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed      df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c      ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4      cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c      8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b      972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'small_molecule'], axis=1)
# Out:
#          tratamento  tempo dose     g-0  ...    c-96    c-97    c-98    c-99
# 0         com_droga     24   D1  1.0620  ... -0.3981  0.2139  0.3801  0.4176
# 1         com_droga     72   D1  0.0743  ...  0.1522  0.1241  0.6077  0.7371
# 2         com_droga     48   D1  0.6280  ... -0.6417 -0.2187 -1.4080  0.6931
# 3         com_droga     48   D1 -0.5138  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4         com_droga     72   D2 -0.3254  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...    ...  ...     ...  ...     ...     ...     ...     ...
# 23809     com_droga     24   D2  0.1394  ...  0.0631  0.9171  0.5258  0.4680
# 23810     com_droga     24   D2 -1.3260  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  com_controle     48   D2  0.3942  ...  0.2256  0.7592  0.6656  0.3808
# 23812     com_droga     24   D1  0.6660  ...  0.1732  0.7015 -0.6290  0.0740
# 23813     com_droga     72   D1 -0.8598  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 875 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'small_molecule'], axis=1)
x = pd.get_dummies(x, columns=['dose', 'tratamento', 'tempo'])
y = dados_combinados['ativo_moa']
x_test, x_treino, y_test, y_treino = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_test, y_test)
# Out:
# 0.6806466852133747
